# %% [markdown]
# Roll Number: CH.SC.U4CSE24123
# Name: M A Kaushik
# DECISION TREE CLASSIFIER 2

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
data = {
    'weather': ['sunny', 'sunny', 'sunny', 'sunny', 'sunny',
                'rainy', 'rainy', 'rainy', 'rainy', 'rainy'],
    'activity': ['picnic', 'drinks with colleague', 'errands', 'picnic', 'drinks with colleague',
                 'watch movie', 'watch movie', 'watch movie', 'watch movie', 'watch movie'],
    'outcome': ['go out', 'go out', 'go out', 'go out', 'go out',
                'stay in', 'stay in', 'stay in', 'stay in', 'stay in']
}
df = pd.DataFrame(data)
df
# Out:
#   weather               activity  outcome
# 0   sunny                 picnic   go out
# 1   sunny  drinks with colleague   go out
# 2   sunny                errands   go out
# 3   sunny                 picnic   go out
# 4   sunny  drinks with colleague   go out
# 5   rainy            watch movie  stay in
# 6   rainy            watch movie  stay in
# 7   rainy            watch movie  stay in
# 8   rainy            watch movie  stay in
# 9   rainy            watch movie  stay in

# %%
le_weather = LabelEncoder()
le_outcome = LabelEncoder()
df['weather_encoded'] = le_weather.fit_transform(df['weather'])   # sunny=1, rainy=0 (order may vary)
df['outcome_encoded'] = le_outcome.fit_transform(df['outcome'])   # go out=0, stay in=1 (order may vary)
df
# Out:
#   weather               activity  outcome  weather_encoded  outcome_encoded
# 0   sunny                 picnic   go out                1                0
# 1   sunny  drinks with colleague   go out                1                0
# 2   sunny                errands   go out                1                0
# 3   sunny                 picnic   go out                1                0
# 4   sunny  drinks with colleague   go out                1                0
# 5   rainy            watch movie  stay in                0                1
# 6   rainy            watch movie  stay in                0                1
# 7   rainy            watch movie  stay in                0                1
# 8   rainy            watch movie  stay in                0                1
# 9   rainy            watch movie  stay in                0                1

# %%
X = df[['weather_encoded']]
y = df['outcome_encoded']

# %%
clf = DecisionTreeClassifier(criterion='gini', random_state=42)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
plt.figure(figsize=(8, 6))
plot_tree(clf,
          feature_names=['weather'],
          class_names=le_outcome.classes_,
          filled=True,
          rounded=True)
plt.title("Classification Tree: Weather → Go Out / Stay In")
plt.show()

# %%
predictions = clf.predict(X)
accuracy = (predictions == y).mean()
print(f"Accuracy: {accuracy * 100:.1f}%")
print("Since every rainy day maps to 'stay in' and every sunny day maps to 'go out',")
print("the single split on 'weather' produces 100% pure leaves — no second split needed.")
# Out:
# Accuracy: 100.0%
# Since every rainy day maps to 'stay in' and every sunny day maps to 'go out',
# the single split on 'weather' produces 100% pure leaves — no second split needed.
